# %% [markdown]
# ## What is Human Action Recognition(HAR)?
#
# - Human activity recognition, or HAR for short, is a broad field of study concerned with identifying the specific movement or action of a person based on sensor data.
# - Movements are often typical activities performed indoors, such as walking, talking, standing, and sitting

# %% [markdown]
# ## Why it is important ?
# - Human activity recognition plays a significant role in human-to-human interaction and interpersonal relations.
# - Because it provides information about the identity of a person, their personality, and psychological state, it is difficult to extract.
# - The human ability to recognize another person’s activities is one of the main subjects of study of the scientific areas of computer vision and machine learning. As a result of this research, many applications, including video surveillance systems, human-computer interaction, and robotics for human behavior characterization, require a multiple activity recognition system.

# %% [markdown]
# ## What is a CNN?
#
# A convolutional neural network (CNN) is a type of artificial neural network used in image recognition and processing that is specifically designed to process pixel data.
#
# CNNs are powerful image processing, artificial intelligence (AI) that use deep learning to perform both generative and descriptive tasks, often using machine vison that includes image and video recognition, along with recommender systems and natural language processing (NLP).
#
# ![cnn](./images/cnn.jpeg)
#
# ## VGG16
#
# VGG-16 is a convolutional neural network that is 16 layers deep. You can load a pretrained version of the network trained on more than a million images from the ImageNet database. The pretrained network can classify images into 1000 object categories, such as keyboard, mouse, pencil, and many animals. As a result, the network has learned rich feature representations for a wide range of images. The network has an image input size of 224-by-224.
#
# ![vgg16](./images/vgg16.png)

# %% [markdown]
# ## What is Transfer Learning
#
# Transfer learning is a machine learning method where a model developed for a task is reused as the starting point for a model on a second task. It is a popular approach in deep learning where pre-trained models are used as the starting point on computer vision and natural language processing tasks given the vast compute and time resources required to develop neural network models on these problems and from the huge jumps in skill that they provide on related problems.
#
# ![transfer learning](./images/transfer.jpeg)

# %% [markdown]
# ## HAR using Transfer Learning

# %% [markdown]
# ## Imports

# %%
# %pip install opencv-python
import os
import glob

#imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

#Scikit Learn
from sklearn.model_selection import train_test_split

#Image processing
import cv2 as cv

# #tensorflow 
# from tensorflow.keras.utils import to_categorical
# import tensorflow as tf
# from tensorflow import keras
# from keras import layers
# from keras.models import Sequential
# from keras.layers import Conv2D,MaxPooling2D,Activation, Dropout, Flatten, Dense
# from keras.preprocessing.image import ImageDataGenerator
# Out:
# Requirement already satisfied: opencv-python in c:\users\uttka\appdata\local\programs\python\python313\lib\site-packages (4.11.0.86)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.21.2 in c:\users\uttka\appdata\local\programs\python\python313\lib\site-packages (from opencv-python) (2.2.2)
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
#Dataframe classifying the actions
train_action = pd.read_csv("data/Training_set.csv")
test_action = pd.read_csv("data/Testing_set.csv")

# %%
train_action.head()
# Out:
#       filename         label
# 0  Image_1.jpg       sitting
# 1  Image_2.jpg  using_laptop
# 2  Image_3.jpg       hugging
# 3  Image_4.jpg      sleeping
# 4  Image_5.jpg  using_laptop

# %% [markdown]
# ## Looking at the data

# %%
#Printing the images along with their respective action

img = cv.imread('data/train/' + train_action.filename[0])
plt.title(train_action.label[0])
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB));

# %%
test_action.shape
# Out:
# (5400, 1)

# %% [markdown]
# There are 12,600 images in the training dataset. Creating a function which will randomly sample a image from the set and print the image along with its labeled action.

# %%
#Sample images and their labels in the training data


def show_img_train():
    img_num = np.random.randint(0,12599)
    img = cv.imread('data/train/' + train_action.filename[img_num])
    plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
    plt.title(train_action.label[img_num])

def show_img_test():
    img_num = np.random.randint(0,5399)
    img = cv.imread('data/test/' + test_action.filename[img_num])
    plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_train()

# %%
show_img_test()

# %%
show_img_test()

# %% [markdown]
# Note that the images from the test set do not contain the labels. That is for the model to predict.

# %% [markdown]
# ## Plotting the label classes

# %% [markdown]
# ### Pie chart

# %%
l = train_action.label.value_counts()
fig = px.pie(train_action, values=l.values, names=l.index, title='Distribution of Human Activity')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 2
#       1 l = train_action.label.value_counts()
# ----> 2 fig = px.pie(train_action, values=l.values, names=l.index, title='Distribution of Human Activity')
#       3 fig.show()
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_chart_types.py:1701, in pie(data_frame, names, values, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, color_discrete_sequence, color_discrete_map, hover_name, hover_data, custom_data, category_orders, labels, title, subtitle, template, width, height, opacity, hole)
#    1699 else:
#    1700     layout_patch = {}
# -> 1701 return make_figure(
#    1702     args=locals(),
#    1703     constructor=go.Pie,
#    1704     trace_patch=dict(showlegend=(names is not None), hole=hole),
#    1705     layout_patch=layout_patch,
#    1706 )
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_core.py:2479, in make_figure(args, constructor, trace_patch, layout_patch)
#    2476 layout_patch = layout_patch or {}
#    2477 apply_default_cascade(args)
# -> 2479 args = build_dataframe(args, constructor)
#    2480 if constructor in [go.Treemap, go.Sunburst, go.Icicle] and args["path"] is not None:
#    2481     args = process_dataframe_hierarchy(args)
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_core.py:1727, in build_dataframe(args, constructor)
#    1724     args["color"] = None
#    1725 # now that things have been prepped, we do the systematic rewriting of `args`
# -> 1727 df_output, wide_id_vars = process_args_into_dataframe(
#    1728     args,
#    1729     wide_mode,
#    1730     var_name,
#    1731     value_name,
#    1732     is_pd_like,
#    1733     native_namespace,
#    1734 )
#    1735 df_output: nw.DataFrame
#    1736 # now that `df_output` exists and `args` contains only references, we complete
#    1737 # the special-case and wide-mode handling by further rewriting args and/or mutating
#    1738 # df_output
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\express\_core.py:1362, in process_args_into_dataframe(args, wide_mode, var_name, value_name, is_pd_like, native_namespace)
#    1354         col_name = _escape_col_name(
#    1355             df_input.columns, col_name, [var_name, value_name]
#    1356         )
#    1357     else:
#    1358         if (
#    1359             argument.name is not None
#    1360             and argument.name in df_input.columns
#    1361             and (
# -> 1362                 to_named_series(
#    1363                     argument, argument.name, native_namespace
#    1364                 )
#    1365                 == df_input.get_column(argument.name)
#    1366             ).all()
#    1367         ):
#    1368             col_name = argument.name
#    1369 if col_name is None:  # numpy array, list...
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\narwhals\series.py:1532, in Series.__eq__(self, other)
#    1530 def __eq__(self: Self, other: object) -> Self:  # type: ignore[override]
#    1531     return self._from_compliant_series(
# -> 1532         self._compliant_series.__eq__(self._extract_native(other))
#    1533     )
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\narwhals\_pandas_like\series.py:387, in PandasLikeSeries.__eq__(self, other)
#     386 def __eq__(self: Self, other: object) -> PandasLikeSeries:  # type: ignore[override]
# --> 387     ser, other = align_and_extract_native(self, other)
#     388     return self._from_native_series(ser == other).alias(self.name)
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\narwhals\_pandas_like\utils.py:119, in align_and_extract_native(lhs, rhs)
#     115     rhs_native = rhs._native_series
#     116     if rhs_native.index is not lhs_index:
#     117         return (
#     118             lhs_native,
# --> 119             set_index(
#     120                 rhs_native,
#     121                 lhs_index,
#     122                 implementation=rhs._implementation,
#     123                 backend_version=rhs._backend_version,
#     124             ),
#     125         )
#     126     return (lhs_native, rhs_native)
#     128 if isinstance(rhs, list):
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\narwhals\_pandas_like\utils.py:291, in set_index(obj, index, implementation, backend_version)
#     289 else:  # pragma: no cover
#     290     pass
# --> 291 return obj.set_axis(index, axis=0, **kwargs)
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\series.py:5133, in Series.set_axis(self, labels, axis, copy)
#    5100 @Appender(
#    5101     """
#    5102     Examples
#    (...)
#    5131     copy: bool | None = None,
#    5132 ) -> Series:
# -> 5133     return super().set_axis(labels, axis=axis, copy=copy)
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:792, in NDFrame.set_axis(self, labels, axis, copy)
#     746 def set_axis(
#     747     self,
#     748     labels,
#    (...)
#     751     copy: bool_t | None = None,
#     752 ) -> Self:
#     753     """
#     754     Assign desired index to given axis.
#     755
#    (...)
#     790     %(klass)s.rename_axis : Alter the name of the index%(see_also_sub)s.
#     791     """
# --> 792     return self._set_axis_nocheck(labels, axis, inplace=False, copy=copy)
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:804, in NDFrame._set_axis_nocheck(self, labels, axis, inplace, copy)
#     800 else:
#     801     # With copy=False, we create a new object but don't copy the
#     802     #  underlying data.
#     803     obj = self.copy(deep=copy and not using_copy_on_write())
# --> 804     setattr(obj, obj._get_axis_name(axis), labels)
#     805     return obj
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\Users\uttka\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 12600 elements, new values have 15 elements

# %% [markdown]
# ### Value counts

# %%
train_action.label.value_counts()
# Out:
# label
# sitting               840
# using_laptop          840
# hugging               840
# sleeping              840
# drinking              840
# clapping              840
# dancing               840
# cycling               840
# calling               840
# laughing              840
# eating                840
# fighting              840
# listening_to_music    840
# running               840
# texting               840
# Name: count, dtype: int64

# %% [markdown]
# The output classes for the image classification are balanced. This reduces a step in pre-processing which deals with imbalanced classes using techniques such as SMOTE, under-sampling, etc.

# %% [markdown]
# ## Preprocessing

# %%
img = cv.imread('data/train/' + train_action.filename[0])

#OpenCV reads the images in BGR instead of the standard RGB, hence the below line of code

plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB));
print(img.shape)
# Out:
# (160, 240, 3)

# %% [markdown]
# The inputs for VGG16 model as per the Tensorflow documentation is 224x224. Here out training set images come in all different sizes. We need to resize the images.

# %% [markdown]
# ### Create the directory for resized images

# %% [markdown]
# Skipping the below cell since the folder has already been created.

# %%
#create resized directory in the current project folder
parent_dir = os.getcwd()
directory = 'resized-train'
path = os.path.join(parent_dir, directory)
os.makedirs(path ,exist_ok=True)
print('Created "resized-train" folder')
# Out:
# Created "resized-train" folder

# %% [markdown]
# ## Resize the training images

# %%
#dimensions
width = 224
height = 224
dim = (width, height)

#resizing all the images in the train folder
for i in np.arange(len(train_action.filename)):    
    #read the filename from the dataframe
    filename = train_action.filename.iloc[i]
    #read the image from the train folder
    img = cv.imread('data/train/' + filename)
    #resize the image
    resized = cv.resize(img, dim, interpolation = cv.INTER_AREA)
    #write the image in resized folder
    cv.imwrite('./resized-train/' + filename ,resized)

# %% [markdown]
# ## Resize the test set images

# %%
#create resized directory in the current project folder
parent_dir = os.getcwd()
directory = 'resized-test'
path = os.path.join(parent_dir, directory)
os.makedirs(path, exist_ok=True)
print('Created "resized-test" folder')
# Out:
# Created "resized-test" folder

# %%
#resizing all the images in the train folder
for i in np.arange(len(test_action.filename)):    
    #read the filename from the dataframe
    filename = test_action.filename.iloc[i]
    #read the image from the train folder
    img = cv.imread('data/test/' + filename)
    #resize the image
    resized = cv.resize(img, dim, interpolation = cv.INTER_AREA)
    #write the image in resized folder
    cv.imwrite('./resized-test/' + filename ,resized)

# %% [markdown]
# ## Pre-processing

# %% [markdown]
# ### Display image

# %%
img = cv.imread('resized-train/' + train_action.filename[0])
plt.imshow(cv.cvtColor(img, cv.COLOR_BGR2RGB))
print(img.shape)
# Out:
# (224, 224, 3)

# %% [markdown]
# We can see that the images have been resized and stored in a different directory. This helps us avoid resizing the images everytime we run the notebook.

# %% [markdown]
# ## Read images and convert them into numpy arrays

# %% [markdown]
# ## X

# %%
#empty list train
X = []

#reading all the resized images
for i in np.arange(len(train_action.filename)): 
    img = cv.imread('resized-train/' + train_action.filename[i])
    X.append(img)

X = np.asarray(X)
X.shape
# Out:
# (12600, 224, 224, 3)

# %%
print(train_action.label)
# Out:
# 0                   sitting
# 1              using_laptop
# 2                   hugging
# 3                  sleeping
# 4              using_laptop
#                 ...
# 12595               sitting
# 12596              clapping
# 12597               sitting
# 12598               dancing
# 12599    listening_to_music
# Name: label, Length: 12600, dtype: object

# %% [markdown]
# ## y

# %%
y = np.asarray(pd.get_dummies(train_action.label))
print(y.shape)
# Out:
# (12600, 15)

# %% [markdown]
# ## Test train Split

# %%
print(X.shape,y.shape)
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.1, random_state=42,stratify=train_action.label)
# Out:
# (12600, 224, 224, 3) (12600, 15)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (11340, 224, 224, 3) (11340, 15)

# %% [markdown]
# ## Unseen test set
#
# This set of images are meant to be submitted on Kaggle. We wont be using this data for this project.

# %%
#empty list test
X_unseen = []

#reading all the resized images
for i in np.arange(len(test_action.filename)): 
    img = cv.imread('resized-test/' + test_action.filename[i])
    X_unseen.append(img)

X_unseen = np.asarray(X_unseen)
X_unseen.shape
# Out:
# (5400, 224, 224, 3)

# %% [markdown]
# ## Building the CNN model using transfer learning

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.utils import to_categorical
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense
import tensorflow as tf

# Initialize a VGG16 without the top layers
pretrained_model = tf.keras.applications.VGG16(
    include_top=False,
    input_shape=(224, 224, 3),
    pooling='avg',
    classes=15,  # Number of classes in your dataset
    weights='imagenet'
)

# Freezing the deeper layers
for layer in pretrained_model.layers:
    layer.trainable = False

# Constructing the CNN model
cnn_model = Sequential()
cnn_model.add(pretrained_model)
cnn_model.add(Flatten())
cnn_model.add(Dense(512, activation='relu'))
cnn_model.add(Dense(15, activation='softmax'))  # Number of output classes

# Display the model summary
print(cnn_model.summary())

# Compile the model
cnn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Define the ModelCheckpoint callback
checkpoint_callback = ModelCheckpoint(
    filepath='ckpt/best_model.weights.h5',        # Filepath to save the model
    monitor='loss',                  # Monitor the training loss (or 'val_loss' for validation loss)
    mode = 'min',
    save_best_only=True,             # Save only the best model
    save_weights_only=True,         # Save the entire model, not just weights
    verbose=1                        # Print a message when saving
)

# Train the model with ModelCheckpoint
history = cnn_model.fit(
    X_train, y_train,
    epochs=50,
    callbacks=[checkpoint_callback]  # Include the callback in the training
)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ vgg16 (Functional)              │ (None, 512)            │    14,714,688 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 512)            │       262,656 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 15)             │         7,695 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 14,985,039 (57.16 MB)
#  Trainable params: 270,351 (1.03 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)
# None
# Epoch 1/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.4344 - loss: 2.5491
# Epoch 1: loss improved from inf to 1.76161, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 809s 2s/step - accuracy: 0.4346 - loss: 2.5469
# Epoch 2/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6816 - loss: 0.9659
# Epoch 2: loss improved from 1.76161 to 0.99357, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 809s 2s/step - accuracy: 0.6816 - loss: 0.9660
# Epoch 3/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7625 - loss: 0.7317
# Epoch 3: loss improved from 0.99357 to 0.75773, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 808s 2s/step - accuracy: 0.7625 - loss: 0.7317
# Epoch 4/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8171 - loss: 0.5562
# Epoch 4: loss improved from 0.75773 to 0.57222, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 811s 2s/step - accuracy: 0.8170 - loss: 0.5563
# Epoch 5/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8805 - loss: 0.3792
# Epoch 5: loss improved from 0.57222 to 0.40773, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 801s 2s/step - accuracy: 0.8804 - loss: 0.3793
# Epoch 6/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9137 - loss: 0.2784
# Epoch 6: loss improved from 0.40773 to 0.29929, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 912s 3s/step - accuracy: 0.9136 - loss: 0.2785
# Epoch 7/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9404 - loss: 0.2032
# Epoch 7: loss improved from 0.29929 to 0.20333, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 866s 2s/step - accuracy: 0.9404 - loss: 0.2032
# Epoch 8/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9589 - loss: 0.1430
# Epoch 8: loss improved from 0.20333 to 0.14572, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1020s 3s/step - accuracy: 0.9589 - loss: 0.1430
# Epoch 9/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9696 - loss: 0.1074
# Epoch 9: loss improved from 0.14572 to 0.12590, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1026s 3s/step - accuracy: 0.9696 - loss: 0.1075
# Epoch 10/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9732 - loss: 0.1040
# Epoch 10: loss improved from 0.12590 to 0.11838, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 1023s 3s/step - accuracy: 0.9732 - loss: 0.1041
# Epoch 11/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9736 - loss: 0.0896
# Epoch 11: loss improved from 0.11838 to 0.10043, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 992s 3s/step - accuracy: 0.9736 - loss: 0.0896
# Epoch 12/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9586 - loss: 0.1270
# Epoch 12: loss did not improve from 0.10043
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 841s 2s/step - accuracy: 0.9586 - loss: 0.1270
# Epoch 13/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9638 - loss: 0.1064
# Epoch 13: loss did not improve from 0.10043
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 841s 2s/step - accuracy: 0.9638 - loss: 0.1064
# Epoch 14/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9684 - loss: 0.0946
# Epoch 14: loss improved from 0.10043 to 0.08203, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 841s 2s/step - accuracy: 0.9684 - loss: 0.0946
# Epoch 15/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9815 - loss: 0.0578
# Epoch 15: loss improved from 0.08203 to 0.06623, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 853s 2s/step - accuracy: 0.9815 - loss: 0.0578
# Epoch 16/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9797 - loss: 0.0626
# Epoch 16: loss did not improve from 0.06623
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9797 - loss: 0.0626
# Epoch 17/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9666 - loss: 0.1066
# Epoch 17: loss did not improve from 0.06623
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 840s 2s/step - accuracy: 0.9665 - loss: 0.1067
# Epoch 18/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9661 - loss: 0.1000
# Epoch 18: loss did not improve from 0.06623
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 840s 2s/step - accuracy: 0.9661 - loss: 0.1000
# Epoch 19/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9743 - loss: 0.0808
# Epoch 19: loss did not improve from 0.06623
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 841s 2s/step - accuracy: 0.9743 - loss: 0.0808
# Epoch 20/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9726 - loss: 0.0807
# Epoch 20: loss did not improve from 0.06623
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 839s 2s/step - accuracy: 0.9726 - loss: 0.0807
# Epoch 21/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9800 - loss: 0.0587
# Epoch 21: loss improved from 0.06623 to 0.05158, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 836s 2s/step - accuracy: 0.9800 - loss: 0.0587
# Epoch 22/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9890 - loss: 0.0409
# Epoch 22: loss did not improve from 0.05158
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 837s 2s/step - accuracy: 0.9890 - loss: 0.0410
# Epoch 23/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9829 - loss: 0.0521
# Epoch 23: loss improved from 0.05158 to 0.04960, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9829 - loss: 0.0521
# Epoch 24/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9776 - loss: 0.0713
# Epoch 24: loss did not improve from 0.04960
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 842s 2s/step - accuracy: 0.9776 - loss: 0.0714
# Epoch 25/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9648 - loss: 0.1105
# Epoch 25: loss did not improve from 0.04960
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 842s 2s/step - accuracy: 0.9649 - loss: 0.1105
# Epoch 26/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9856 - loss: 0.0399
# Epoch 26: loss improved from 0.04960 to 0.04725, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 841s 2s/step - accuracy: 0.9856 - loss: 0.0399
# Epoch 27/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9883 - loss: 0.0357
# Epoch 27: loss improved from 0.04725 to 0.02721, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 855s 2s/step - accuracy: 0.9883 - loss: 0.0357
# Epoch 28/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9915 - loss: 0.0251
# Epoch 28: loss did not improve from 0.02721
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 839s 2s/step - accuracy: 0.9915 - loss: 0.0251
# Epoch 29/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9656 - loss: 0.1091
# Epoch 29: loss did not improve from 0.02721
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9656 - loss: 0.1091
# Epoch 30/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9748 - loss: 0.0693
# Epoch 30: loss did not improve from 0.02721
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9748 - loss: 0.0692
# Epoch 31/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9856 - loss: 0.0399
# Epoch 31: loss did not improve from 0.02721
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 837s 2s/step - accuracy: 0.9856 - loss: 0.0399
# Epoch 32/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9701 - loss: 0.0884
# Epoch 32: loss did not improve from 0.02721
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 836s 2s/step - accuracy: 0.9701 - loss: 0.0883
# Epoch 33/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9703 - loss: 0.0987
# Epoch 33: loss did not improve from 0.02721
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 836s 2s/step - accuracy: 0.9703 - loss: 0.0986
# Epoch 34/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9901 - loss: 0.0323
# Epoch 34: loss did not improve from 0.02721
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 839s 2s/step - accuracy: 0.9901 - loss: 0.0322
# Epoch 35/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9896 - loss: 0.0295
# Epoch 35: loss improved from 0.02721 to 0.02340, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9896 - loss: 0.0295
# Epoch 36/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9898 - loss: 0.0326
# Epoch 36: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 835s 2s/step - accuracy: 0.9898 - loss: 0.0327
# Epoch 37/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9672 - loss: 0.1184
# Epoch 37: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 837s 2s/step - accuracy: 0.9672 - loss: 0.1184
# Epoch 38/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9859 - loss: 0.0552
# Epoch 38: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 837s 2s/step - accuracy: 0.9860 - loss: 0.0552
# Epoch 39/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9837 - loss: 0.0537
# Epoch 39: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 835s 2s/step - accuracy: 0.9837 - loss: 0.0537
# Epoch 40/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9872 - loss: 0.0405
# Epoch 40: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 839s 2s/step - accuracy: 0.9872 - loss: 0.0405
# Epoch 41/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9891 - loss: 0.0383
# Epoch 41: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9891 - loss: 0.0383
# Epoch 42/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9852 - loss: 0.0497
# Epoch 42: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9852 - loss: 0.0497
# Epoch 43/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9833 - loss: 0.0646
# Epoch 43: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9833 - loss: 0.0645
# Epoch 44/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9884 - loss: 0.0403
# Epoch 44: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 836s 2s/step - accuracy: 0.9883 - loss: 0.0403
# Epoch 45/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9828 - loss: 0.0610
# Epoch 45: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 840s 2s/step - accuracy: 0.9828 - loss: 0.0611
# Epoch 46/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9844 - loss: 0.0512
# Epoch 46: loss did not improve from 0.02340
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 838s 2s/step - accuracy: 0.9844 - loss: 0.0512
# Epoch 47/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9930 - loss: 0.0222
# Epoch 47: loss improved from 0.02340 to 0.02110, saving model to ckpt/best_model.weights.h5
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 836s 2s/step - accuracy: 0.9930 - loss: 0.0222
# Epoch 48/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9873 - loss: 0.0442
# Epoch 48: loss did not improve from 0.02110
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 816s 2s/step - accuracy: 0.9873 - loss: 0.0443
# Epoch 49/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9787 - loss: 0.0827
# Epoch 49: loss did not improve from 0.02110
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 804s 2s/step - accuracy: 0.9787 - loss: 0.0826
# Epoch 50/50
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9899 - loss: 0.0327
# Epoch 50: loss did not improve from 0.02110
# 355/355 ━━━━━━━━━━━━━━━━━━━━ 804s 2s/step - accuracy: 0.9899 - loss: 0.0328

# %% [markdown]
# # Save the best model

# %%
cnn_model.load_weights('ckpt/best_model.weights.h5')
cnn_model.save('model/cnn_model.keras')

# %%
#plotting the loss
loss = history.history['loss']

plt.title("Loss Function")
plt.xlabel("epochs")
sns.set_theme(style='darkgrid')
sns.lineplot(loss)
# Out:
# <Axes: title={'center': 'Loss Function'}, xlabel='epochs'>

# %%
plt.title("Accuracy")
plt.xlabel("epochs")
accu = history.history['accuracy']
sns.lineplot(accu)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.title("Accuracy")
#       2 plt.xlabel("epochs")
#       3 accu = history.history['accuracy']
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ## Predictions

# %%
y_preds = cnn_model.predict(X_test)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step

# %% [markdown]
# ## Accuracy and Log Loss

# %%
from sklearn.metrics import accuracy_score, log_loss

print('Log Loss:',log_loss(np.round(y_preds),y_test))
print('Accuracy:',accuracy_score(np.round(y_preds),y_test))
# Out:
# Log Loss: 7.208730677823431
# Accuracy: 0.4849206349206349

# %% [markdown]
# ## Visualizing the predictions

# %%
from PIL import Image
import matplotlib.image as mimg

#reading image and resize 
def read_image(fn):
    image = Image.open(fn)
    return np.asarray(image.resize((224,224)))

#predict the class and the confidence of the prediction
def test_predict(test_image):
    result = cnn_model.predict(np.asarray([read_image(test_image)]))

    itemindex = np.where(result==np.max(result))
    prediction = itemindex[1][0]
    print("probability: "+str(np.max(result)*100) + "%\nPredicted class : ", prediction)

    image = mimg.imread(test_image)
    plt.imshow(image)
    plt.title(prediction)

# %%
#Image 1
filename = test_action.filename.iloc[200]
test_predict('./resized-test/' + filename)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 65ms/step
# probability: 78.8952112197876%
# Predicted class :  8

# %%
#Image 2
filename = test_action.filename.iloc[10]
test_predict('./resized-test/' + filename)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# probability: 96.65806889533997%
# Predicted class :  9

# %% [markdown]
# ## Next Steps and Recommendations
#
#
# - In order to improve the accuracy, we can unfreeze few more layers and retrain the model. This will help us further improve the model.
#
# - We can tune the parameters using KerasTuner.
#
# - The model reached a good accuracy score after the 20 epochs but it has been trained for 60 epochs. There is definitely some overfitting which can avoided with early stopping.
#
# - The nodes in the deep layers were connected. We can introduce some amount dropout for regularization.
